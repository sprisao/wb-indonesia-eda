# %%
import pandas as pd
import os

# %%
data_dir = '../data/csv/original/second/'
data_list = os.listdir(data_dir)
data_list
# Out:
# ['By Sectors-By Sectors (World Bank definition) (Nominal Bil. IDR).csv',
#  'By Economic classification-By Economic classification (Nominal Bil. IDR).csv',
#  'By Functions-By Functions (Government of Indonesia  on the effort to be accordance with COFOG definition) (Nominal Bil. IDR).csv']

# %%
function_df = pd.read_csv(data_dir + data_list[2], header=1, skipinitialspace=True)

# %%
function_df
# Out:
#    Central (excl. transfers, subsidy and interest payment)+provinces+districts   \
# 0                           1_General Public Services
# 1                                           2_Defense
# 2                           3_Public Order and Safety
# 3                                  4_Economic Affairs
# 4                          5_Environmental Protection
# 5                6_Housing and Communities Ammenities
# 6                                            7_Health
# 7                               8_Tourism and Culture
# 8                                          9_Religion
# 9                                        10_Education
# 10                               11_Social Protection
# 11             No Function nor Subfunction and others
# 12          Total (excl.subsidy and interest payment)
# 13                                          Subsidies
# 14                                  Interest payments
# 15         Total (incl. subsidy and interest payment)
# ...

# %%
function_df = function_df.drop(16, axis=0)

# %%
function_df
# Out:
#    Central (excl. transfers, subsidy and interest payment)+provinces+districts   \
# 0                           1_General Public Services
# 1                                           2_Defense
# 2                           3_Public Order and Safety
# 3                                  4_Economic Affairs
# 4                          5_Environmental Protection
# 5                6_Housing and Communities Ammenities
# 6                                            7_Health
# 7                               8_Tourism and Culture
# 8                                          9_Religion
# 9                                        10_Education
# 10                               11_Social Protection
# 11             No Function nor Subfunction and others
# 12          Total (excl.subsidy and interest payment)
# 13                                          Subsidies
# 14                                  Interest payments
# 15         Total (incl. subsidy and interest payment)
# ...

# %%
function_df.rename(columns={function_df.columns[0]: 'Year'}, inplace=True)
function_df = function_df.set_index('Year')

# %%
function_df
# Out:
#                                                     2007       2008  \
# Year
# 1_General Public Services                        180,543    286,144
# 2_Defense                                         30,686      9,159
# 3_Public Order and Safety                         31,100     10,469
# 4_Economic Affairs                                72,130     84,903
# 5_Environmental Protection                        10,826     12,639
# 6_Housing and Communities Ammenities              62,262     77,543
# 7_Health                                          41,508     45,255
# 8_Tourism and Culture                              4,020      3,765
# 9_Religion                                         1,884        746
# 10_Education                                     124,004    142,500
# 11_Social Protection                               6,648      7,573
# No Function nor Subfunction and others               -61          0
# Total (excl.subsidy and interest payment)        565,550    680,694
# ...

# %%
function_df = function_df.transpose()

# %%
function_df
# Out:
# Year 1_General Public Services 2_Defense 3_Public Order and Safety  \
# 2007                   180,543    30,686                    31,100
# 2008                   286,144     9,159                    10,469
# 2009                   302,665    13,146                    11,758
# 2010                   311,227    17,081                    18,022
# 2011                   253,136    51,121                    26,486
# 2012                   369,683    61,227                    34,806
# 2013                   434,732    87,510                    43,968
# 2014                   465,122    86,113                    48,068
# 2015                   523,539   105,907                    62,130
# 2016                   325,137    98,249                   126,687
# 2017                   305,676   117,507                   152,656
# 2018                   339,552   106,832                   164,049
# 2019                   434,746   115,425                   163,980
# ...

# %%
# save as json
function_df.to_json('../data/json/second/second_byFunctions.json')
