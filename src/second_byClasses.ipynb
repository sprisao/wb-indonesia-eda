# %%
import pandas as pd
import os

# %%
data_dir = '../data/csv/original/second/'
data_list = os.listdir(data_dir)
data_list
# Out:
# ['By Sectors-By Sectors (World Bank definition) (Nominal Bil. IDR).csv',
#  'By Economic classification-By Economic classification (Nominal Bil. IDR).csv',
#  'By Functions-By Functions (Government of Indonesia  on the effort to be accordance with COFOG definition) (Nominal Bil. IDR).csv']

# %%
class_df = pd.read_csv(data_dir + data_list[1], header=1, skipinitialspace=True)

# %%
class_df
# Out:
#    Central (excl. transfers, subsidy and interest payment)+provinces+districts  \
# 0                                         1_Personnel
# 1                                2_Goods and services
# 2                                           3_Capital
# 3                                            4_Grants
# 4   5_Others (include financial/social assistance ...
# 5         6_Social Assistance (only at central level)
# 6          Total (excl. subsidy and interest payment)
# 7                                           Subsidies
# 8                                   Interest payments
# 9          Total (incl. subsidy and interest payment)
# 10                                   For information:
# 11    Transfers (from Central to sub-national levels)
#
#        2001     2002     2003     2004     2005     2006     2007       2008  \
# 0    85,104   86,154  109,702  126,677  132,353  167,556  211,616    261,345
# 1    30,227   40,389   47,805   49,593   68,854  105,155  110,363    122,548
# ...

# %%
class_df = class_df.drop(10, axis=0)

# %%
class_df
# Out:
#    Central (excl. transfers, subsidy and interest payment)+provinces+districts  \
# 0                                         1_Personnel
# 1                                2_Goods and services
# 2                                           3_Capital
# 3                                            4_Grants
# 4   5_Others (include financial/social assistance ...
# 5         6_Social Assistance (only at central level)
# 6          Total (excl. subsidy and interest payment)
# 7                                           Subsidies
# 8                                   Interest payments
# 9          Total (incl. subsidy and interest payment)
# 11    Transfers (from Central to sub-national levels)
#
#        2001     2002     2003     2004     2005     2006     2007       2008  \
# 0    85,104   86,154  109,702  126,677  132,353  167,556  211,616    261,345
# 1    30,227   40,389   47,805   49,593   68,854  105,155  110,363    122,548
# ...

# %%
class_df.rename(columns={class_df.columns[0]: 'Year'}, inplace=True)
class_df = class_df.set_index('Year')

# %%
class_df
# Out:
#                                                        2001     2002     2003  \
# Year
# 1_Personnel                                          85,104   86,154  109,702
# 2_Goods and services                                 30,227   40,389   47,805
# 3_Capital                                            58,398   61,604  102,772
# 4_Grants                                                  -        -        -
# 5_Others (include financial/social assistance i...   14,221   20,299   28,442
# 6_Social Assistance (only at central level)             NaN      NaN      NaN
# Total (excl. subsidy and interest payment)          187,950  208,446  288,720
# Subsidies                                            77,443   40,006   43,899
# Interest payments                                    87,142   87,667   65,351
# Total (incl. subsidy and interest payment)          352,536  336,119  397,969
# Transfers (from Central to sub-national levels)      81,054   94,657  120,314
#
# ...

# %%
class_df = class_df.transpose()

# %%
class_df
# Out:
# Year 1_Personnel 2_Goods and services 3_Capital 4_Grants  \
# 2001      85,104               30,227    58,398        -
# 2002      86,154               40,389    61,604        -
# 2003     109,702               47,805   102,772        -
# 2004     126,677               49,593    92,241        -
# 2005     132,353               68,854    69,931        -
# 2006     167,556              105,155   119,802        -
# 2007     211,616              110,363   152,854    3,916
# 2008     261,345              122,548   170,638   11,352
# 2009     295,891              155,791   178,323   11,782
# 2010     348,955              178,306   174,451   15,231
# 2011     406,226              230,617   226,214   18,586
# 2012     458,807              261,398   275,147   46,513
# 2013     514,048              315,330   368,450   53,144
# 2014     556,475              342,018   328,340   54,439
# 2015     610,335              426,136   424,088   69,188
# ...

# %%
# save as json
class_df.to_json('../data/json/second/second_byFunctions.json')
